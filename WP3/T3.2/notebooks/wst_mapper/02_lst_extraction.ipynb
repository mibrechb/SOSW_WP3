# %%
import ee
import geemap
import functions_process as funcs_process
import functions_masking as funcs_masking
import functions_sampling as funcs_sampling
from pathlib import Path
from tqdm.notebook import tqdm
import geopandas as gpd
import pandas as pd
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Authenticate()
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 2
#       1 ee.Authenticate()
# ----> 2 ee.Initialize()
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\ee\_utils.py:38, in accept_opt_prefix.<locals>.opt_fixed.<locals>.wrapper(*args, **kwargs)
#      36     if new_key not in kwargs:
#      37       kwargs[new_key] = old_key_val
# ---> 38 return func(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\ee\__init__.py:160, in Initialize(credentials, url, cloud_api_key, http_transport, project)
#     157 if not project and oauth.is_sdk_credentials(credentials):
#     158   raise EEException(NO_PROJECT_EXCEPTION)
# --> 160 data.initialize(
#     161     credentials=credentials,
#     162     api_base_url=(url + '/api' if url else None),
#     163     tile_base_url=url,
#     164     cloud_api_base_url=url,
#     165     cloud_api_key=cloud_api_key,
#     166     project=project,
#     167     http_transport=http_transport,
#     168 )
#     170 # Initialize the dynamically loaded functions on the objects that want them.
#     171 try:
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\ee\data.py:225, in initialize(credentials, api_base_url, tile_base_url, cloud_api_base_url, cloud_api_key, project, http_transport)
#     222 if _requests_session is None:
#     223   _requests_session = requests.Session()
# --> 225 _install_cloud_api_resource()
#     227 if project is not None:
#     228   _cloud_api_user_project = project
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\ee\data.py:319, in _install_cloud_api_resource()
#     317 timeout = (_deadline_ms / 1000.0) or None
#     318 assert _requests_session is not None
# --> 319 _cloud_api_resource = _cloud_api_utils.build_cloud_resource(
#     320     _cloud_api_base_url,
#     321     _requests_session,
#     322     credentials=_credentials,
#     323     api_key=_cloud_api_key,
#     324     timeout=timeout,
#     325     headers_supplier=_make_request_headers,
#     326     response_inspector=_handle_profiling_response,
#     327     http_transport=_http_transport,
#     328 )
#     330 _cloud_api_resource_raw = _cloud_api_utils.build_cloud_resource(
#     331     _cloud_api_base_url,
#     332     _requests_session,
#    (...)
#     339     raw=True,
#     340 )
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\ee\_cloud_api_utils.py:207, in build_cloud_resource(api_base_url, session, api_key, credentials, timeout, headers_supplier, response_inspector, http_transport, raw)
#     202 resource = None
#     203 try:
#     204   # google-api-python-client made static_discovery the default in version 2,
#     205   # but it's not backward-compatible. There's no reliable way to check the
#     206   # package version, either.
# --> 207   resource = build(static_discovery=False)
#     208 except TypeError:
#     209   pass  # Handle fallback case outside except block, for cleaner stack traces.
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\ee\_cloud_api_utils.py:191, in build_cloud_resource.<locals>.build(**kwargs)
#     190 def build(**kwargs):
# --> 191   return discovery.build(
#     192       'earthengine',
#     193       VERSION,
#     194       discoveryServiceUrl=discovery_service_url,
#     195       developerKey=api_key,
#     196       http=http_transport,
#     197       requestBuilder=request_builder,
#     198       model=alt_model,
#     199       cache_discovery=False,
#     200       **kwargs)
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\googleapiclient\discovery.py:304, in build(serviceName, version, http, discoveryServiceUrl, developerKey, model, requestBuilder, credentials, cache_discovery, cache, client_options, adc_cert_path, adc_key_path, num_retries, static_discovery, always_use_jwt_access)
#     301 requested_url = uritemplate.expand(discovery_url, params)
#     303 try:
# --> 304     content = _retrieve_discovery_doc(
#     305         requested_url,
#     306         discovery_http,
#     307         cache_discovery,
#     308         serviceName,
#     309         version,
#     310         cache,
#     311         developerKey,
#     312         num_retries=num_retries,
#     313         static_discovery=static_discovery,
#     314     )
#     315     service = build_from_document(
#     316         content,
#     317         base=discovery_url,
#    (...)
#     326         always_use_jwt_access=always_use_jwt_access,
#     327     )
#     328     break  # exit if a service was created
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\googleapiclient\discovery.py:439, in _retrieve_discovery_doc(url, http, cache_discovery, serviceName, version, cache, developerKey, num_retries, static_discovery)
#     436 # Execute this request with retries build into HttpRequest
#     437 # Note that it will already raise an error if we don't get a 2xx response
#     438 req = HttpRequest(http, HttpRequest.null_postproc, actual_url)
# --> 439 resp, content = req.execute(num_retries=num_retries)
#     441 try:
#     442     content = content.decode("utf-8")
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\googleapiclient\http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\googleapiclient\http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\ee\_cloud_api_utils.py:70, in _Http.request(***failed resolving arguments***)
#      63 del redirections  # Ignored
#      65 try:
#      66   # googleapiclient is expecting an httplib2 object, and doesn't include
#      67   # requests error in the list of transient errors. Therefore, transient
#      68   # requests errors should be converted to kinds that googleapiclient
#      69   # consider transient.
# ---> 70   response = self._session.request(
#      71       method, uri, data=body, headers=headers, timeout=self._timeout
#      72   )
#      73 except requests.exceptions.ConnectionError as connection_error:
#      74   raise ConnectionError(connection_error) from connection_error
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\http\client.py:1419, in HTTPConnection.getresponse(self)
#    1417 try:
#    1418     try:
# -> 1419         response.begin()
#    1420     except ConnectionError:
#    1421         self.close()
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\ssl.py:1253, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1249     if flags != 0:
#    1250         raise ValueError(
#    1251           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1252           self.__class__)
# -> 1253     return self.read(nbytes, buffer)
#    1254 else:
#    1255     return super().recv_into(buffer, nbytes, flags)
#
# File c:\ProgramData\Anaconda3\envs\earth-engine\Lib\ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# %load_ext autoreload
# %autoreload 2
import functions_process as funcs_process
import functions_sampling as funcs_sampling

# prepare insitu data
path_data = Path('data/insitu/parsed/lubw_rhine_stations.csv') # Baden-Württemberg Rhine stations (3)
#path_data = Path('data/insitu/parsed/bs_rhine_station.csv') # Basel-stadt Weil am Rhein station
df = gpd.read_file(path_data, ignore_geometry=True)
df['geometry'] = gpd.GeoSeries.from_wkt(df['geometry'], crs='epsg:4326')
gdf_data = gpd.GeoDataFrame(df)

# filter hour of day
# gdf_data['dt64'] = pd.to_datetime(gdf_data.dt64, utc=True)
# gdf_data = gdf_data.loc[pd.to_datetime(gdf_data.dt64).dt.hour==9]

tasks = []
for identifier in tqdm(gdf_data.station_id.unique()):
    fn = identifier
    gdf_data_station = gdf_data.loc[gdf_data.station_id==identifier]
    dates = gdf_data_station.sort_values('dt64').dt64
    start_date, end_date = dates.iloc[0], dates.iloc[-1]
    fc_station = ee.FeatureCollection(geemap.gdf_to_ee(
        gdf_data_station, 
        date='dt64', date_format='YYYY-MM-dd'))
        #date='dt64', date_format="YYYY-MM-dd'T'HH:mm:ss'Z'"))
    bounds = fc_station.geometry()
    ic_st = funcs_process.load_st_imcoll(start_date, end_date, bounds, cld_buffer=250, water_buffer=100, watermask='qa')
    fc_matchups = funcs_sampling.get_matchups(fc_station, ic_st, max_diff=0.5) \
        .map(funcs_sampling.get_sample)
    task = ee.batch.Export.table.toDrive(**{
        'collection': fc_matchups, 
        'description': f'LST_{fn}',
        'folder': 'SOSW_LST_24042024'})
    task.start()
    tasks.append(task)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
Map = geemap.Map()
Map.add_basemap("Esri.WorldImagery")
Map.add_basemap("OpenTopoMap")
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
img = ic_st.first()

landsat_tirs = {
    'min': 273.15,
    'max': 293.15,
    'bands': ['ST'],
    'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5']
}

Map.addLayer(img, {}, 'Landsat LST')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import time
from datetime import datetime, timedelta

def check_tasks_status(tasks):
    """ Check the state of all provided ee.task objects and posts status updates. """
    colordict = {'white': '\033[0m', 'red': '\033[91m', 'orange': '\033[93m', 'green': '\033[92m'}
    states = []
    for task in tasks:
        # get state and times
        status = task.status()
        state = status['state']
        task_id = status['id']
        time_start, time_update = status['creation_timestamp_ms'], status['update_timestamp_ms']
        time_elapsed = timedelta(milliseconds=(time_update-time_start))
        time_now = datetime.now()
        # set output color
        if state == 'COMPLETED':
            color ='green'
        elif (state == 'RUNNING') | (state == 'READY'):
            color = 'orange'
        elif (state == 'FAILED') | (state == 'CANCEL_REQUESTED') | (state == 'CANCELLED'):
            color = 'red'
        else:
            color = 'white'
        # print msg
        status_msg = f"[{str(time_now)[:19]}] Task {task_id}" \
                     f"({status.get('description', 'No description')}): {colordict[color]+state+colordict['white']}"
                     #f" (runtime: {time_elapsed.seconds/60:0.1f}min)"
        print(status_msg)
        states.append(state)
    return states

all_completed = False
while not all_completed:
    check_tasks_status(tasks)
    states = [task.status()['state'] for task in tasks]
    if all(state in ['COMPLETED', 'FAILED', 'CANCEL_REQUESTED'] for state in states):
        all_completed = True
        
    else:
        time.sleep(30)
n_failed = sum([state in ['FAILED', 'CANCEL_REQUESTED'] for state in states])
print(f"All export tasks finished ({n_failed} tasks failed).")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [2024-04-25 13:25:11] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:25:11] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): RUNNING
# [2024-04-25 13:25:12] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): READY
# [2024-04-25 13:25:43] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:25:44] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): RUNNING
# [2024-04-25 13:25:44] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): READY
# [2024-04-25 13:26:15] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:26:16] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): RUNNING
# [2024-04-25 13:26:16] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): READY
# [2024-04-25 13:26:47] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:26:47] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): RUNNING
# [2024-04-25 13:26:48] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): READY
# [2024-04-25 13:27:19] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:27:20] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): RUNNING
# [2024-04-25 13:27:20] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): READY
# [2024-04-25 13:27:52] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:27:52] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): RUNNING
# [2024-04-25 13:27:52] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): READY
# [2024-04-25 13:28:24] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:28:24] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): RUNNING
# [2024-04-25 13:28:25] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): READY
# [2024-04-25 13:28:56] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:28:56] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): RUNNING
# [2024-04-25 13:28:57] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): READY
# [2024-04-25 13:29:29] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:29:29] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): RUNNING
# [2024-04-25 13:29:29] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): READY
# [2024-04-25 13:30:01] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:30:02] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): RUNNING
# [2024-04-25 13:30:02] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): READY
# [2024-04-25 13:30:33] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:30:33] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): COMPLETED
# [2024-04-25 13:30:34] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): RUNNING
# [2024-04-25 13:31:05] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:31:06] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): COMPLETED
# [2024-04-25 13:31:06] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): RUNNING
# [2024-04-25 13:31:37] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:31:38] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): COMPLETED
# [2024-04-25 13:31:38] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): RUNNING
# [2024-04-25 13:32:09] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:32:10] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): COMPLETED
# [2024-04-25 13:32:10] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): RUNNING
# [2024-04-25 13:32:41] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:32:41] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): COMPLETED
# [2024-04-25 13:32:42] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): RUNNING
# [2024-04-25 13:33:13] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:33:13] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): COMPLETED
# [2024-04-25 13:33:14] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): RUNNING
# [2024-04-25 13:33:45] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:33:46] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): COMPLETED
# [2024-04-25 13:33:46] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): COMPLETED
# [2024-04-25 13:34:17] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): RUNNING
# [2024-04-25 13:34:18] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): COMPLETED
# [2024-04-25 13:34:18] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): COMPLETED
# [2024-04-25 13:34:49] Task OLGTPZJGYVRGVGSKACE4OSDD(LST_CXX334): COMPLETED
# [2024-04-25 13:34:50] Task WM66G3G346NKQE2YM35I4KGP(LST_CXX359): COMPLETED
# [2024-04-25 13:34:50] Task KZJX4WDBSUQVWD6F363MT67R(LST_CXX147): COMPLETED
# All export tasks finished (0 tasks failed).

# %%
import ast 

path_drive = Path(r"G:\Meine Ablage\Earth Engine\SOSW_LST_24042024")
paths_csv = list(path_drive.glob('*.csv'))

df = pd.DataFrame([])
for path in paths_csv:
    print(f'Reading file {path.name}..')
    try:
        df_temp = pd.read_csv(path)
        df = pd.concat([df, df_temp])
    except pd.errors.EmptyDataError:
        print(f'Note: {path.name} was empty. Skipping.')
        continue # will skip the rest of the block and move to next file

def parse_str_dict(string):
    string = string.replace('=', '":').replace(', ', ', "').replace('null', 'None')[1:-1]
    string = '{"' + string +'}'
    parsed_dict = dict(ast.literal_eval(string))
    return parsed_dict

df['values_eo'] = df.values_eo.apply(parse_str_dict)
df_values_eo = df['values_eo'].apply(pd.Series)
df = pd.concat([df.drop('values_eo', axis=1), df_values_eo], axis=1)
df['ST_deg'] = df['ST']-273.15
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Reading file LST_bs_war.csv..
# Reading file LST_CXX359.csv..
# Reading file LST_CXX334.csv..
# Reading file LST_CXX147.csv..

# %%
import plotly.express as px
import plotly.graph_objects as go
from scipy.stats import linregress
import numpy as np
import math

x_name, y_name = 'ST_deg', 'temperature'

ds_dt64 = pd.to_datetime(df.timestamp)
ds_hour = ds_dt64.dt.hour + ds_dt64.dt.minute / 60 + ds_dt64.dt.second / 3600

fig = px.scatter(df, x=x_name, y=y_name, 
                 #color="sensor", 
                 custom_data='station_id',
                 facet_col="station_id",
                 width=1200, height=400,
                 trendline="ols", 
                 opacity=0.5,
                 color='sensor',
                 labels={
                     'temperature': "T<sub>insitu</sub>",
                     'ST_deg': "T<sub>Landsat</sub>"
                 },
                 template="simple_white")

fig.update_layout(
    margin=dict(l=20, r=20, t=20, b=20),
    xaxis=dict(scaleanchor="y", scaleratio=1),  # Ensuring equal scaling
    yaxis=dict(constrain='domain'),  # Ensuring y-axis adjusts to match x-axis scale
    #paper_bgcolor="LightSteelBlue",
)

def get_lingress_dict(x, y):
    """ Fit linear regression and get statistics."""
    x = x.dropna()
    y = y.loc[x.index]
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    predicted_y = slope * x + intercept
    mse = np.mean((y - predicted_y) ** 2)
    return {'intercept': intercept,
            'slope': slope,
            'p': p_value,
            'r': r_value,
            'r2': r_value**2,
            'mse': mse,
            'rmse': np.sqrt(mse)
            }

lims = [
    min(df[x_name].min(), df[y_name].min()),  # Find the lower bound
    max(df[x_name].max(), df[y_name].max())   # Find the upper bound
]

for idx, group in enumerate(df.groupby('station_id')):
    id = group[0]
    df_group = group[1]
    x, y = df_group.ST_deg, df_group.temperature
    statdict = get_lingress_dict(x, y)
    # add annotation
    fig.add_annotation(x=2, y=25,
                align='left',
                xref=f'x{idx+1}',
                yref=f'y{idx+1}',
                text=(f'<b>R2:</b> {statdict['r2']:0.2f}<br>' \
                      f'<b>MSE:</b> {statdict['mse']:0.2f}<br>' \
                      f'<b>RMSE:</b> {statdict['rmse']:0.2f}'),
                showarrow=False,
                yshift=10)
    fig.add_trace(go.Scatter(x=lims, y=lims, 
                             mode='lines', name='1:1 Line', line=dict(dash='dash')),
                             row=1, col=idx+1)

fig.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
